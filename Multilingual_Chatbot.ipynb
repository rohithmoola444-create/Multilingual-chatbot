# %% [markdown]
# <a href="https://colab.research.google.com/github/rohithmoola444-create/Multilingual-chatbot/blob/main/Multilingual_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=e27bd9aa8ef5ca9a21c8ead39f2691d75357405b7e35a7b5d8858feea0eac3d2
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...

# %%
# ==========================================
# SMARTASSIST MULTILINGUAL CHATBOT
# With Language Selection Option
# ==========================================

import random

# ==========================================
# PROFESSIONAL MULTILINGUAL DATASET
# ==========================================

dataset = {

    # ======================================================
    # ENGLISH
    # ======================================================

    "english": {

        "hello": [
            "Hello! Welcome to our support service. How may I assist you today?",
            "Hi! Thank you for contacting us. How can I help you?",
            "Welcome! Please let me know how I can assist you."
        ],

        "how are you": [
            "I am functioning perfectly and ready to assist you.",
            "I'm doing well. Thank you for asking!",
            "I am operational and happy to help you."
        ],

        "what is your name": [
            "I am SmartAssist, your multilingual virtual assistant.",
            "You may call me SmartAssist. I'm here to support you.",
            "I am an AI-powered multilingual chatbot designed to help users."
        ],

        "what services do you provide": [
            "I can assist with general queries, student support, customer assistance, and multilingual communication.",
            "I provide multilingual support, information assistance, and customer guidance services."
        ],

        "can you help me": [
            "Certainly! Please describe your issue or question.",
            "Of course. Kindly share your query so I can assist you."
        ],

        "thank you": [
            "You're welcome! Have a great day.",
            "Glad I could assist you."
        ],

        "bye": [
            "Thank you for using our service. Have a wonderful day!",
            "Goodbye! Feel free to return if you need further assistance."
        ]
    },

    # ======================================================
    # TELUGU
    # ======================================================

    "telugu": {

        "హలో": [
            "నమస్తే! మా సేవకు స్వాగతం. నేను మీకు ఎలా సహాయం చేయగలను?",
            "హాయ్! మమ్మల్ని సంప్రదించినందుకు ధన్యవాదాలు."
        ],

        "ఎలా ఉన్నావు": [
            "నేను బాగున్నాను మరియు మీకు సహాయం చేయడానికి సిద్ధంగా ఉన్నాను.",
            "ధన్యవాదాలు! నేను చాలా బాగున్నాను."
        ],

        "నీ పేరు ఏమిటి": [
            "నేను SmartAssist అనే మల్టీలింగ్వల్ వర్చువల్ అసిస్టెంట్.",
            "మీరు నన్ను SmartAssist అని పిలవచ్చు."
        ],

        "మీ సేవలు ఏమిటి": [
            "నేను విద్యార్థి సహాయం, కస్టమర్ సపోర్ట్ మరియు సాధారణ సమాచారం అందించగలను.",
            "నేను బహుభాషా సేవలు మరియు సమాచార సహాయం అందిస్తాను."
        ],

        "నాకు సహాయం చేయగలవా": [
            "ఖచ్చితంగా! దయచేసి మీ ప్రశ్నను వివరించండి.",
            "తప్పకుండా. మీ సమస్యను చెప్పండి."
        ],

        "ధన్యవాదాలు": [
            "మీకు స్వాగతం!",
            "మీకు సహాయం చేయగలిగినందుకు సంతోషంగా ఉంది."
        ],

        "బై": [
            "మా సేవను ఉపయోగించినందుకు ధన్యవాదాలు.",
            "వీడ్కోలు! మళ్లీ సహాయం కావాలంటే సంప్రదించండి."
        ]
    },

    # ======================================================
    # HINDI
    # ======================================================

    "hindi": {

        "नमस्ते": [
            "नमस्ते! हमारी सेवा में आपका स्वागत है। मैं आपकी कैसे सहायता कर सकता हूँ?",
            "हैलो! हमसे संपर्क करने के लिए धन्यवाद।"
        ],

        "कैसे हो": [
            "मैं ठीक हूँ और आपकी सहायता के लिए तैयार हूँ।",
            "धन्यवाद! मैं बहुत अच्छा हूँ।"
        ],

        "तुम्हारा नाम क्या है": [
            "मैं SmartAssist नामक multilingual virtual assistant हूँ।",
            "आप मुझे SmartAssist कह सकते हैं।"
        ],

        "आप कौन सी सेवाएं देते हैं": [
            "मैं छात्र सहायता, ग्राहक सहायता और सामान्य जानकारी प्रदान करता हूँ।",
            "मैं बहुभाषी सहायता और सूचना सेवाएं प्रदान करता हूँ।"
        ],

        "क्या आप मेरी मदद कर सकते हैं": [
            "ज़रूर! कृपया अपनी समस्या बताइए।",
            "बिल्कुल। कृपया अपना प्रश्न साझा करें।"
        ],

        "धन्यवाद": [
            "आपका स्वागत है!",
            "मुझे आपकी सहायता करके खुशी हुई।"
        ],

        "बाय": [
            "हमारी सेवा का उपयोग करने के लिए धन्यवाद।",
            "अलविदा! यदि आपको और सहायता चाहिए तो वापस आएँ।"
        ]
    },

    # ======================================================
    # TAMIL
    # ======================================================

    "tamil": {

        "வணக்கம்": [
            "வணக்கம்! எங்கள் சேவைக்கு வரவேற்கிறோம். நான் எப்படி உதவலாம்?",
            "ஹாய்! எங்களை தொடர்பு கொண்டதற்கு நன்றி."
        ],

        "எப்படி இருக்கிறாய்": [
            "நான் நன்றாக இருக்கிறேன் மற்றும் உங்களுக்கு உதவ தயாராக உள்ளேன்.",
            "நன்றி! நான் மிகவும் நன்றாக இருக்கிறேன்."
        ],

        "உன் பெயர் என்ன": [
            "நான் SmartAssist என்ற multilingual virtual assistant.",
            "நீங்கள் என்னை SmartAssist என்று அழைக்கலாம்."
        ],

        "நீங்கள் என்ன சேவைகள் வழங்குகிறீர்கள்": [
            "நான் மாணவர் உதவி, வாடிக்கையாளர் சேவை மற்றும் தகவல் உதவி வழங்குகிறேன்.",
            "நான் பல மொழி உதவி சேவைகள் வழங்குகிறேன்."
        ],

        "நீங்கள் எனக்கு உதவ முடியுமா": [
            "நிச்சயமாக! தயவுசெய்து உங்கள் கேள்வியை பகிருங்கள்.",
            "மிகவும் மகிழ்ச்சி. உங்கள் பிரச்சினையை கூறுங்கள்."
        ],

        "நன்றி": [
            "உங்களை வரவேற்கிறேன்!",
            "உதவியதில் மகிழ்ச்சி."
        ],

        "பை": [
            "எங்கள் சேவையை பயன்படுத்தியதற்கு நன்றி.",
            "பிரியாவிடை! மேலும் உதவி தேவைப்பட்டால் திரும்ப வாருங்கள்."
        ]
    }
}

# ==========================================
# LANGUAGE SELECTION
# ==========================================

print("================================================")
print("      SMARTASSIST MULTILINGUAL CHATBOT")
print("================================================")
print("Select Your Language:")
print("1. English")
print("2. Telugu")
print("3. Hindi")
print("4. Tamil")
print("================================================")

choice = input("Enter your choice (1/2/3/4): ")

# Language Mapping

language_map = {
    "1": "english",
    "2": "telugu",
    "3": "hindi",
    "4": "tamil"
}

selected_language = language_map.get(choice, "english")

print("\n================================================")
print("Chatbot Started Successfully")
print("Type 'exit' to end the conversation")
print("================================================")

# ==========================================
# CHATBOT RESPONSE FUNCTION
# ==========================================

def chatbot_response(user_input, language):

    user_input_lower = user_input.lower()

    for question in dataset[language]:

        if question.lower() in user_input_lower:

            return random.choice(dataset[language][question])

    # Professional fallback responses

    fallback = {

        "english":
        "I apologize, but I could not understand your request. Could you please rephrase it?",

        "telugu":
        "క్షమించండి, మీ అభ్యర్థనను అర్థం చేసుకోలేకపోయాను. దయచేసి మళ్లీ వివరించండి.",

        "hindi":
        "क्षमा कीजिए, मैं आपके अनुरोध को समझ नहीं पाया। कृपया दोबारा बताइए।",

        "tamil":
        "மன்னிக்கவும், உங்கள் கோரிக்கையை புரிந்துகொள்ள முடியவில்லை. தயவுசெய்து மீண்டும் கூறுங்கள்."
    }

    return fallback[language]

# ==========================================
# MAIN CHAT LOOP
# ==========================================

while True:

    user_input = input("\nYou: ")

    if user_input.lower() == "exit":

        goodbye_messages = {

            "english":
            "Thank you for using SmartAssist. Have a great day!",

            "telugu":
            "SmartAssist ఉపయోగించినందుకు ధన్యవాదాలు. మీ రోజు శుభంగా గడవాలి!",

            "hindi":
            "SmartAssist का उपयोग करने के लिए धन्यवाद। आपका दिन शुभ हो!",

            "tamil":
            "SmartAssist பயன்படுத்தியதற்கு நன்றி. உங்கள் நாள் இனிதாக அமையட்டும்!"
        }

        print("\nBot:", goodbye_messages[selected_language])
        break

    response = chatbot_response(user_input, selected_language)

    print("\nBot:", response)
# Out:
# ...
#       SMARTASSIST MULTILINGUAL CHATBOT
# ...
# Select Your Language:
# 1. English
# 2. Telugu
# 3. Hindi
# 4. Tamil
# ...
# Enter your choice (1/2/3/4): 3
#
# ...
# Chatbot Started Successfully
# Type 'exit' to end the conversation
# ...
#
# You: नमस्ते
#
# Bot: हैलो! हमसे संपर्क करने के लिए धन्यवाद।
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_785/1638175373.py in <cell line: 0>()
#     255 while True:
#     256
# --> 257     user_input = input("\nYou: ")
#     258
#     259     if user_input.lower() == "exit":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
